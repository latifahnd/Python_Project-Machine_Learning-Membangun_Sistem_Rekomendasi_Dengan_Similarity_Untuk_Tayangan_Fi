# %% [markdown]
# # Machine Learning: Membangun Sistem Rekomendasi Dengan Similarity Untuk Tayangan Film
# #### by: Nadia Fitriana Latifah

# %% [markdown]
# ## Overview
# #### Pada project machine learning sebelumnya, sudah dibuat sistem rekomendasi untuk tayangan film dengan menggunakan IMDB average rating dengan mengurutkan value yang pada setiap data di film secara descending, sehingga dapat diketahui suatu film atau beberapa film yang menarik menurut para penonton.
# #### Dalam project machine learning ini akan dibuat suatu sistem rekomendasi untuk tayangan film dengan menggunakan content atau feature dari film tersebut, kemudian melakukan perhitungan terhadap kesamaan antara satu film dengan film lainnya, sehingga jika ditunjuk satu film akan mendapatkan beberapa film lain yang memiliki kesamaan dengan film yang telah ditunjuk tersebut. Kondisi seperti ini disebut sebagai Content Based Recommender System.
# #### Dengan membandingkan kesamaan genre yang ada, sebagai contoh ketika penonton lebih menyukai film Narnia, maka Content Based Recommender System ini akan merekomendasikan film seperti Harry Potter atau The Lords of The Rings yang memiliki genre yang mirip.

# %%
import numpy as np
import pandas as pd

# %%
df_film_rating=pd.read_csv('movie_rating_df.csv')

# %%
df_film_rating
# Out:
#            tconst  titleType            primaryTitle           originalTitle  \
# 0       tt0000001      short              Carmencita              Carmencita
# 1       tt0000002      short  Le clown et ses chiens  Le clown et ses chiens
# 2       tt0000003      short          Pauvre Pierrot          Pauvre Pierrot
# 3       tt0000004      short             Un bon bock             Un bon bock
# 4       tt0000005      short        Blacksmith Scene        Blacksmith Scene
# ...           ...        ...                     ...                     ...
# 751609  tt9916538      movie     Kuambil Lagi Hatiku     Kuambil Lagi Hatiku
# 751610  tt9916544      short         My Sweet Prince         My Sweet Prince
# 751611  tt9916576  tvEpisode        Destinee's Story        Destinee's Story
# 751612  tt9916720      short               The Nun 2               The Nun 2
# 751613  tt9916766  tvEpisode          Episode #10.15          Episode #10.15
#
#         isAdult  startYear  endYear  runtimeMinutes                    genres  \
# 0             0     1894.0      NaN             1.0         Documentary,Short
# 1             0     1892.0      NaN             5.0           Animation,Short
# 2             0     1892.0      NaN             4.0  Animation,Comedy,Romance
# 3             0     1892.0      NaN            12.0           Animation,Short
# 4             0     1893.0      NaN             1.0              Comedy,Short
# ...         ...        ...      ...             ...                       ...
# 751609        0     2019.0      NaN           123.0                       NaN
# 751610        0     2019.0      NaN            12.0               Drama,Short
# 751611        0     2019.0      NaN            85.0                       NaN
# 751612        0     2019.0      NaN            10.0     Comedy,Horror,Mystery
# 751613        0     2019.0      NaN            43.0         Family,Reality-TV
#
#         averageRating  numVotes
# 0                 5.6      1608
# 1                 6.0       197
# 2                 6.5      1285
# 3                 6.1       121
# 4                 6.1      2050
# ...               ...       ...
# 751609            8.4         5
# 751610            7.2        19
# 751611            6.0         9
# 751612            5.6        49
# 751613            6.8        13
#
# [751614 rows x 11 columns]

# %%
df_film_rating.shape
# Out:
# (751614, 11)

# %%
df_film_rating.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#    isAdult  startYear  endYear  runtimeMinutes                    genres  \
# 0        0     1894.0      NaN             1.0         Documentary,Short
# 1        0     1892.0      NaN             5.0           Animation,Short
# 2        0     1892.0      NaN             4.0  Animation,Comedy,Romance
# 3        0     1892.0      NaN            12.0           Animation,Short
# 4        0     1893.0      NaN             1.0              Comedy,Short
#
#    averageRating  numVotes
# 0            5.6      1608
# 1            6.0       197
# 2            6.5      1285
# 3            6.1       121
# 4            6.1      2050

# %% [markdown]
# #### Untuk mengetahui jenis tipe data pada file movie_rating_df

# %%
df_film_rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 751614 entries, 0 to 751613
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          751614 non-null  object
#  1   titleType       751614 non-null  object
#  2   primaryTitle    751614 non-null  object
#  3   originalTitle   751614 non-null  object
#  4   isAdult         751614 non-null  int64
#  5   startYear       751614 non-null  float64
#  6   endYear         16072 non-null   float64
#  7   runtimeMinutes  751614 non-null  float64
#  8   genres          486766 non-null  object
#  9   averageRating   751614 non-null  float64
#  10  numVotes        751614 non-null  int64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 63.1+ MB

# %% [markdown]
# ### Add Actors DataFrame
# #### Dari hasil output pada project machine learning sebelumnya, diperoleh list film dengan beberapa metadata sepertu isAdult, runtimeMinutes, dan genres dari setiap film.
# #### Untuk project machine learning ini, akan ditambahkan metadata lain seperti aktor atau aktris yang bermain pada film tersebut. Selain itu, juga akan digunakan DataFrame lain yang kemudian akan dilakukan join dengan DataFrame df_film_rating.

# %%
df_nama_aktor=pd.read_csv('actor_name.csv')

# %%
df_nama_aktor
# Out:
#          nconst          primaryName birthYear deathYear  \
# 0     nm1774132    Nathan McLaughlin      1973        \N
# 1    nm10683464        Bridge Andrew        \N        \N
# 2     nm1021485    Brandon Fransvaag        \N        \N
# 3     nm6940929   Erwin van der Lely        \N        \N
# 4     nm5764974  Svetlana Shypitsyna        \N        \N
# ..          ...                  ...       ...       ...
# 995   nm7596674         Paul Whitrow        \N        \N
# 996   nm5938546          Wendy Ponce        \N        \N
# 997   nm2101810         Ans Brugmans        \N        \N
# 998   nm5245804        Eliza Jenkins        \N        \N
# 999   nm0948460           Greg Yolen        \N        \N
#
#                             primaryProfession  \
# 0          special_effects,make_up_department
# 1                                       actor
# 2                               miscellaneous
# 3                               miscellaneous
# 4                                     actress
# ..                                        ...
# 995                                     actor
# 996                                       NaN
# 997                          costume_designer
# 998                                       NaN
# 999  cinematographer,camera_department,writer
#
#                               knownForTitles
# 0    tt0417686,tt1713976,tt1891860,tt0454839
# 1                                  tt7718088
# 2                                  tt0168790
# 3                                  tt4232168
# 4                                  tt3014168
# ..                                       ...
# 995  tt4118352,tt9104322,tt4447090,tt4892804
# 996                                tt2125666
# 997                                tt0488280
# 998                                tt1464058
# 999  tt0436869,tt0476663,tt0109723,tt0364484
#
# [1000 rows x 6 columns]

# %%
df_nama_aktor.shape
# Out:
# (1000, 6)

# %%
df_nama_aktor.head()
# Out:
#        nconst          primaryName birthYear deathYear  \
# 0   nm1774132    Nathan McLaughlin      1973        \N
# 1  nm10683464        Bridge Andrew        \N        \N
# 2   nm1021485    Brandon Fransvaag        \N        \N
# 3   nm6940929   Erwin van der Lely        \N        \N
# 4   nm5764974  Svetlana Shypitsyna        \N        \N
#
#                     primaryProfession                           knownForTitles
# 0  special_effects,make_up_department  tt0417686,tt1713976,tt1891860,tt0454839
# 1                               actor                                tt7718088
# 2                       miscellaneous                                tt0168790
# 3                       miscellaneous                                tt4232168
# 4                             actress                                tt3014168

# %% [markdown]
# #### Untuk mengetahui jenis tipe data pada file actor_name

# %%
df_nama_aktor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   nconst             1000 non-null   object
#  1   primaryName        1000 non-null   object
#  2   birthYear          1000 non-null   object
#  3   deathYear          1000 non-null   object
#  4   primaryProfession  891 non-null    object
#  5   knownForTitles     1000 non-null   object
# dtypes: object(6)
# memory usage: 47.0+ KB

# %% [markdown]
# ### Add Directors and Writers DataFrame
# #### Pada langkah ini, ditambahkan DataFrame berupa directors dan writers dari setiap film.

# %%
df_director_writer=pd.read_csv('directors_writers.csv')

# %%
df_director_writer
# Out:
#         tconst                   director_name  \
# 0    tt0011414                  David Kirkland
# 1    tt0011890               Roy William Neill
# 2    tt0014341  Buster Keaton,John G. Blystone
# 3    tt0018054                Cecil B. DeMille
# 4    tt0024151                     James Cruze
# ..         ...                             ...
# 981  tt9236688                      Kai Wessel
# 982  tt9278408                    Bahadir Ince
# 983  tt9285882                          Rapman
# 984  tt9310372                     Sujoy Ghosh
# 985  tt9355200                 Johannes Nyholm
#
#                                            writer_name
# 0                              John Emerson,Anita Loos
# 1         Arthur F. Goodrich,Burns Mantle,Mary Murillo
# 2      Jean C. Havez,Clyde Bruckman,Joseph A. Mitchell
# 3                                    Jeanie Macpherson
# 4                     Max Miller,Wells Root,Jack Jevne
# ..                                                 ...
# 981                                  Christian Jeltsch
# 982            Levent Cantek,Ali Demirel,Baris Erdogan
# 983                                             Rapman
# 984  Sujoy Ghosh,Raj Vasant,Pratim D. Gupta,Suresh ...
# 985                                    Johannes Nyholm
#
# [986 rows x 3 columns]

# %%
df_director_writer.shape
# Out:
# (986, 3)

# %%
df_director_writer.head()
# Out:
#       tconst                   director_name  \
# 0  tt0011414                  David Kirkland
# 1  tt0011890               Roy William Neill
# 2  tt0014341  Buster Keaton,John G. Blystone
# 3  tt0018054                Cecil B. DeMille
# 4  tt0024151                     James Cruze
#
#                                        writer_name
# 0                          John Emerson,Anita Loos
# 1     Arthur F. Goodrich,Burns Mantle,Mary Murillo
# 2  Jean C. Havez,Clyde Bruckman,Joseph A. Mitchell
# 3                                Jeanie Macpherson
# 4                 Max Miller,Wells Root,Jack Jevne

# %% [markdown]
# #### Untuk mengetahui jenis tipe data pada file directors_writers

# %%
df_director_writer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         986 non-null    object
#  1   director_name  986 non-null    object
#  2   writer_name    986 non-null    object
# dtypes: object(3)
# memory usage: 23.2+ KB

# %% [markdown]
# ### Converting into List Data
# #### Setelah mengetahui informasi dari file directors_writers dapat diketahui bahwa tidak ada nilai NULL pada DataFrame tersebut. Langkah selanjutnya adalah mengubah director_name dan writer_name dari data string menjadi bentuk data list.

# %%
df_director_writer['director_name']=df_director_writer['director_name'].apply(lambda row: row.split(','))
df_director_writer['writer_name']=df_director_writer['writer_name'].apply(lambda row: row.split(','))

# %%
df_director_writer
# Out:
#         tconst                      director_name  \
# 0    tt0011414                   [David Kirkland]
# 1    tt0011890                [Roy William Neill]
# 2    tt0014341  [Buster Keaton, John G. Blystone]
# 3    tt0018054                 [Cecil B. DeMille]
# 4    tt0024151                      [James Cruze]
# ..         ...                                ...
# 981  tt9236688                       [Kai Wessel]
# 982  tt9278408                     [Bahadir Ince]
# 983  tt9285882                           [Rapman]
# 984  tt9310372                      [Sujoy Ghosh]
# 985  tt9355200                  [Johannes Nyholm]
#
#                                            writer_name
# 0                           [John Emerson, Anita Loos]
# 1     [Arthur F. Goodrich, Burns Mantle, Mary Murillo]
# 2    [Jean C. Havez, Clyde Bruckman, Joseph A. Mitc...
# 3                                  [Jeanie Macpherson]
# 4                 [Max Miller, Wells Root, Jack Jevne]
# ..                                                 ...
# 981                                [Christian Jeltsch]
# 982        [Levent Cantek, Ali Demirel, Baris Erdogan]
# 983                                           [Rapman]
# 984  [Sujoy Ghosh, Raj Vasant, Pratim D. Gupta, Sur...
# 985                                  [Johannes Nyholm]
#
# [986 rows x 3 columns]

# %%
df_director_writer.head()
# Out:
#       tconst                      director_name  \
# 0  tt0011414                   [David Kirkland]
# 1  tt0011890                [Roy William Neill]
# 2  tt0014341  [Buster Keaton, John G. Blystone]
# 3  tt0018054                 [Cecil B. DeMille]
# 4  tt0024151                      [James Cruze]
#
#                                          writer_name
# 0                         [John Emerson, Anita Loos]
# 1   [Arthur F. Goodrich, Burns Mantle, Mary Murillo]
# 2  [Jean C. Havez, Clyde Bruckman, Joseph A. Mitc...
# 3                                [Jeanie Macpherson]
# 4               [Max Miller, Wells Root, Jack Jevne]

# %% [markdown]
# ### Cleaning and Processing Table Cast
# #### Pada tahap ini dilakukan penghapusan data yang mempunyai nilai NULL dan menghapus kolom-kolom yang tidak digunakan.
# #### Update pada file df_nama_aktor, disini hanya dibutuhkan kolom nconst, primaryName, dan knownForTitles.

# %%
df_nama_aktor=df_nama_aktor[['nconst','primaryName','knownForTitles']]

# %%
df_nama_aktor
# Out:
#          nconst          primaryName                           knownForTitles
# 0     nm1774132    Nathan McLaughlin  tt0417686,tt1713976,tt1891860,tt0454839
# 1    nm10683464        Bridge Andrew                                tt7718088
# 2     nm1021485    Brandon Fransvaag                                tt0168790
# 3     nm6940929   Erwin van der Lely                                tt4232168
# 4     nm5764974  Svetlana Shypitsyna                                tt3014168
# ..          ...                  ...                                      ...
# 995   nm7596674         Paul Whitrow  tt4118352,tt9104322,tt4447090,tt4892804
# 996   nm5938546          Wendy Ponce                                tt2125666
# 997   nm2101810         Ans Brugmans                                tt0488280
# 998   nm5245804        Eliza Jenkins                                tt1464058
# 999   nm0948460           Greg Yolen  tt0436869,tt0476663,tt0109723,tt0364484
#
# [1000 rows x 3 columns]

# %%
df_nama_aktor.head()
# Out:
#        nconst          primaryName                           knownForTitles
# 0   nm1774132    Nathan McLaughlin  tt0417686,tt1713976,tt1891860,tt0454839
# 1  nm10683464        Bridge Andrew                                tt7718088
# 2   nm1021485    Brandon Fransvaag                                tt0168790
# 3   nm6940929   Erwin van der Lely                                tt4232168
# 4   nm5764974  Svetlana Shypitsyna                                tt3014168

# %% [markdown]
# ### Aktor pada Film
# #### Langkah selanjutnya adalah mengetahui variasi dari jumlah film yang diperankan oleh seorang aktor.
# #### Setiap aktor dapat membintangi lebih dari satu film, sehingga diperlukan tabel yang mempunyai relasi bernilai 1-1 ke masing-masing judul film tersebut. Oleh karena itu, perlu dilakukan unnest terhadap tabel tersebut.
# #### Tahapan yang dilakukan pada tahap ini adalah:
# #### 1. Melakukan pengecekan variasi jumlah film yang diperankan oleh aktor.
# #### 2. Mengubah tipe data dari kolom 'knownForTitles' menjadi tipe data list of list.

# %%
#melakukan pengecekan variasi dari jumlah film yang diperankan oleh aktor
print(df_nama_aktor['knownForTitles'].apply(lambda x: len(x.split(','))).unique())
# Out:
# [4 1 2 3]

# %%
#Mengubah tipe data dari kolom 'knownForTitles' menjadi tipe data list of list.
df_nama_aktor['knownForTitles']=df_nama_aktor['knownForTitles'].apply(lambda x: x.split(','))
# Out:
# <ipython-input-24-c695d719424a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nama_aktor['knownForTitles']=df_nama_aktor['knownForTitles'].apply(lambda x: x.split(','))

# %%
df_nama_aktor
# Out:
#          nconst          primaryName  \
# 0     nm1774132    Nathan McLaughlin
# 1    nm10683464        Bridge Andrew
# 2     nm1021485    Brandon Fransvaag
# 3     nm6940929   Erwin van der Lely
# 4     nm5764974  Svetlana Shypitsyna
# ..          ...                  ...
# 995   nm7596674         Paul Whitrow
# 996   nm5938546          Wendy Ponce
# 997   nm2101810         Ans Brugmans
# 998   nm5245804        Eliza Jenkins
# 999   nm0948460           Greg Yolen
#
#                                    knownForTitles
# 0    [tt0417686, tt1713976, tt1891860, tt0454839]
# 1                                     [tt7718088]
# 2                                     [tt0168790]
# 3                                     [tt4232168]
# 4                                     [tt3014168]
# ..                                            ...
# 995  [tt4118352, tt9104322, tt4447090, tt4892804]
# 996                                   [tt2125666]
# 997                                   [tt0488280]
# 998                                   [tt1464058]
# 999  [tt0436869, tt0476663, tt0109723, tt0364484]
#
# [1000 rows x 3 columns]

# %%
df_nama_aktor.head()
# Out:
#        nconst          primaryName  \
# 0   nm1774132    Nathan McLaughlin
# 1  nm10683464        Bridge Andrew
# 2   nm1021485    Brandon Fransvaag
# 3   nm6940929   Erwin van der Lely
# 4   nm5764974  Svetlana Shypitsyna
#
#                                  knownForTitles
# 0  [tt0417686, tt1713976, tt1891860, tt0454839]
# 1                                   [tt7718088]
# 2                                   [tt0168790]
# 3                                   [tt4232168]
# 4                                   [tt3014168]

# %% [markdown]
# ### Relasi untuk Korespondensi 1-1
# #### Pada data sebelumnya dapat diketahui bahwa satu aktor dapat memerankan 1-4 film, maka diperlukan table yang mempunyai relasi korespondensi 1-1 dari aktor ke masing-masing judul film tersebut.

# %%
#Menyiapkan bucket untuk DataFrame
df_uni=[]

for x in ['knownForTitles']: #Mengulang index dari tiap baris pada 'knownForTitles' 
    idx=df_nama_aktor.index.repeat(df_nama_aktor['knownForTitles'].str.len())
    
    #Memecahkan values dari list di setiap baris dan menggabungkannya dengan baris lain menjadi DataFrame.
    df_value_list=pd.DataFrame({
        x: np.concatenate(df_nama_aktor[x].values)
    })
    
    #Mengganti index DataFrame tersebut dengan idx yang sudah didefinisikan di awal.
    df_value_list.index=idx
    
    #Untuk setiap DataFrame yang terbentuk, langkah selanjutnya adalah append ke DataFrame dari bucket.
    df_uni.append(df_value_list)
    
#Menggabungkan semua DataFrame menjadi satu.
df_concat=pd.concat(df_uni, axis=1)

#Left join dengan value dari DataFrame yang awal.
df_unnested=df_concat.join(df_nama_aktor.drop(['knownForTitles'], 1), how='left')

#Select kolom sesuai dengan DataFrame awal.
df_unnested=df_unnested[df_nama_aktor.columns.tolist()]
df_unnested
# Out:
#          nconst        primaryName knownForTitles
# 0     nm1774132  Nathan McLaughlin      tt0417686
# 0     nm1774132  Nathan McLaughlin      tt1713976
# 0     nm1774132  Nathan McLaughlin      tt1891860
# 0     nm1774132  Nathan McLaughlin      tt0454839
# 1    nm10683464      Bridge Andrew      tt7718088
# ..          ...                ...            ...
# 998   nm5245804      Eliza Jenkins      tt1464058
# 999   nm0948460         Greg Yolen      tt0436869
# 999   nm0948460         Greg Yolen      tt0476663
# 999   nm0948460         Greg Yolen      tt0109723
# 999   nm0948460         Greg Yolen      tt0364484
#
# [1918 rows x 3 columns]

# %%
df_unnested.shape
# Out:
# (1918, 3)

# %%
df_unnested.head()
# Out:
#        nconst        primaryName knownForTitles
# 0   nm1774132  Nathan McLaughlin      tt0417686
# 0   nm1774132  Nathan McLaughlin      tt1713976
# 0   nm1774132  Nathan McLaughlin      tt1891860
# 0   nm1774132  Nathan McLaughlin      tt0454839
# 1  nm10683464      Bridge Andrew      tt7718088

# %%
df_unnested.head(20)
# Out:
#        nconst          primaryName knownForTitles
# 0   nm1774132    Nathan McLaughlin      tt0417686
# 0   nm1774132    Nathan McLaughlin      tt1713976
# 0   nm1774132    Nathan McLaughlin      tt1891860
# 0   nm1774132    Nathan McLaughlin      tt0454839
# 1  nm10683464        Bridge Andrew      tt7718088
# 2   nm1021485    Brandon Fransvaag      tt0168790
# 3   nm6940929   Erwin van der Lely      tt4232168
# 4   nm5764974  Svetlana Shypitsyna      tt3014168
# 5   nm8621807          Utku Arslan      tt5493404
# 5   nm8621807          Utku Arslan      tt7661932
# 5   nm8621807          Utku Arslan      tt0845088
# 5   nm8621807          Utku Arslan      tt9278408
# 6   nm0415875         Mihály Jakab      tt0242160
# 7   nm7082726       Ernesto Ballén      tt8696516
# 7   nm7082726       Ernesto Ballén      tt6407610
# 7   nm7082726       Ernesto Ballén      tt2707408
# 7   nm7082726       Ernesto Ballén      tt4392976
# 8   nm5903442            Jen Brown      tt3145724
# 9   nm1744604  Tatyana Kuzmichyova      tt0420982
# 9   nm1744604  Tatyana Kuzmichyova      tt1186366

# %% [markdown]
# ### Nesting pada primaryName group by knownForTitles
# #### Melakukan grouping kembali pada kolom player karena yang diperlukan adalah level movie untuk melakukan rekomendasi film

# %%
drop_unnested=df_unnested.drop(['nconst'], axis=1)

#Menyiapkan busket untuk DataFrame
df_uni=[]

for kolom_player in ['primaryName']:
    #Agergasi pada kolom primaryName sesuai dengan group_kolom_player yang sudah didefinisikan diatas.
    df_kolom=drop_unnested.groupby(['knownForTitles'])[kolom_player].apply(list)
    #Melakukan append
    df_uni.append(df_kolom)
    
df_grouping=pd.concat(df_uni, axis=1).reset_index()
df_grouping.columns=['knownForTitles','cast_name']
df_grouping
# Out:
#      knownForTitles           cast_name
# 0         tt0008125    [Charles Harley]
# 1         tt0009706    [Charles Harley]
# 2         tt0010304  [Natalie Talmadge]
# 3         tt0011414  [Natalie Talmadge]
# 4         tt0011890  [Natalie Talmadge]
# ...             ...                 ...
# 1893      tt9610496  [Stefano Baffetti]
# 1894      tt9714030        [Kevin Kain]
# 1895      tt9741820   [Caroline Plyler]
# 1896      tt9759814     [Ethan Francis]
# 1897      tt9856236     [Nuala Maguire]
#
# [1898 rows x 2 columns]

# %%
df_grouping.shape
# Out:
# (1898, 2)

# %%
df_grouping.head(20)
# Out:
#    knownForTitles                          cast_name
# 0       tt0008125                   [Charles Harley]
# 1       tt0009706                   [Charles Harley]
# 2       tt0010304                 [Natalie Talmadge]
# 3       tt0011414                 [Natalie Talmadge]
# 4       tt0011890                 [Natalie Talmadge]
# 5       tt0014341                 [Natalie Talmadge]
# 6       tt0016622                    [Booth Grainge]
# 7       tt0018054                    [Reeka Roberts]
# 8       tt0024151                    [James Hackett]
# 9       tt0025981                   [Bernard Loftus]
# 10      tt0027332  [Chill Wills and His Avalon Boys]
# 11      tt0027415  [Chill Wills and His Avalon Boys]
# 12      tt0028326                   [Bernard Loftus]
# 13      tt0028657                   [Bernard Loftus]
# 14      tt0029994                   [Bernard Loftus]
# 15      tt0030392                  [Valeene Calkins]
# 16      tt0030399                    [Veronika Radó]
# 17      tt0035802                       [Joe Naster]
# 18      tt0036126                    [James Hackett]
# 19      tt0036400                 [Tomohisa Higuchi]

# %% [markdown]
# ### Joining with Movie Table
# #### Tahapan yang dilakukan pada joining ini antara lain:
# #### 1. Join antara movie table dengan cast table (field of knownForTitles dan tconst).
# #### 2. Join antara df_base dengan df_director_writer (field of tconst and tconst)

# %%
#Join antara movie table dengan cast table
df_base=pd.merge(df_grouping, df_film_rating, left_on='knownForTitles', right_on='tconst', how='inner')

#Join antara df_base dengan df_director_writer
df_base=pd.merge(df_base, df_director_writer, left_on='tconst', right_on='tconst', how='left')

# %%
df_base
# Out:
#      knownForTitles              cast_name     tconst     titleType  \
# 0         tt0011414     [Natalie Talmadge]  tt0011414         movie
# 1         tt0011890     [Natalie Talmadge]  tt0011890         movie
# 2         tt0014341     [Natalie Talmadge]  tt0014341         movie
# 3         tt0018054        [Reeka Roberts]  tt0018054         movie
# 4         tt0024151        [James Hackett]  tt0024151         movie
# ...             ...                    ...        ...           ...
# 1055      tt9246600       [Vanessa Hanson]  tt9246600      tvSeries
# 1056      tt9278408          [Utku Arslan]  tt9278408  tvMiniSeries
# 1057      tt9285882     [Jonathon Deering]  tt9285882         movie
# 1058      tt9310372         [Sandini Dhar]  tt9310372      tvSeries
# 1059      tt9355200  [Lars-Gunnar Thorell]  tt9355200         movie
#
#                 primaryTitle           originalTitle  isAdult  startYear  \
# 0            The Love Expert         The Love Expert        0     1920.0
# 1                  Yes or No               Yes or No        0     1920.0
# 2            Our Hospitality         Our Hospitality        0     1923.0
# 3          The King of Kings       The King of Kings        0     1927.0
# 4     I Cover the Waterfront  I Cover the Waterfront        0     1933.0
# ...                      ...                     ...      ...        ...
# 1055             UFC on ESPN             UFC on ESPN        0     2019.0
# 1056                  Bozkir                  Bozkir        0     2018.0
# 1057              Blue Story              Blue Story        0     2019.0
# 1058              Typewriter              Typewriter        0     2019.0
# 1059         Koko-di Koko-da         Koko-di Koko-da        0     2019.0
#
#       endYear  runtimeMinutes                   genres  averageRating  \
# 0         NaN            60.0           Comedy,Romance            4.9
# 1         NaN            72.0                      NaN            6.3
# 2         NaN            65.0  Comedy,Romance,Thriller            7.8
# 3         NaN           155.0  Biography,Drama,History            7.3
# 4         NaN            80.0            Drama,Romance            6.3
# ...       ...             ...                      ...            ...
# 1055      NaN           180.0                      NaN            8.1
# 1056   2019.0            50.0      Crime,Drama,Mystery            8.2
# 1057      NaN            91.0              Crime,Drama            5.5
# 1058      NaN            48.0          Horror,Thriller            6.5
# 1059      NaN            86.0    Comedy,Fantasy,Horror            6.2
#
#       numVotes                      director_name  \
# 0          136                   [David Kirkland]
# 1            7                [Roy William Neill]
# 2         9621  [Buster Keaton, John G. Blystone]
# 3         1826                 [Cecil B. DeMille]
# 4          455                      [James Cruze]
# ...        ...                                ...
# 1055        38                                NaN
# 1056      1231                     [Bahadir Ince]
# 1057      1411                           [Rapman]
# 1058      2895                      [Sujoy Ghosh]
# 1059       779                  [Johannes Nyholm]
#
#                                             writer_name
# 0                            [John Emerson, Anita Loos]
# 1      [Arthur F. Goodrich, Burns Mantle, Mary Murillo]
# 2     [Jean C. Havez, Clyde Bruckman, Joseph A. Mitc...
# 3                                   [Jeanie Macpherson]
# 4                  [Max Miller, Wells Root, Jack Jevne]
# ...                                                 ...
# 1055                                                NaN
# 1056        [Levent Cantek, Ali Demirel, Baris Erdogan]
# 1057                                           [Rapman]
# 1058  [Sujoy Ghosh, Raj Vasant, Pratim D. Gupta, Sur...
# 1059                                  [Johannes Nyholm]
#
# [1060 rows x 15 columns]

# %%
df_base.shape
# Out:
# (1060, 15)

# %%
df_base.head()
# Out:
#   knownForTitles           cast_name     tconst titleType  \
# 0      tt0011414  [Natalie Talmadge]  tt0011414     movie
# 1      tt0011890  [Natalie Talmadge]  tt0011890     movie
# 2      tt0014341  [Natalie Talmadge]  tt0014341     movie
# 3      tt0018054     [Reeka Roberts]  tt0018054     movie
# 4      tt0024151     [James Hackett]  tt0024151     movie
#
#              primaryTitle           originalTitle  isAdult  startYear  \
# 0         The Love Expert         The Love Expert        0     1920.0
# 1               Yes or No               Yes or No        0     1920.0
# 2         Our Hospitality         Our Hospitality        0     1923.0
# 3       The King of Kings       The King of Kings        0     1927.0
# 4  I Cover the Waterfront  I Cover the Waterfront        0     1933.0
#
#    endYear  runtimeMinutes                   genres  averageRating  numVotes  \
# 0      NaN            60.0           Comedy,Romance            4.9       136
# 1      NaN            72.0                      NaN            6.3         7
# 2      NaN            65.0  Comedy,Romance,Thriller            7.8      9621
# 3      NaN           155.0  Biography,Drama,History            7.3      1826
# 4      NaN            80.0            Drama,Romance            6.3       455
#
#                        director_name  \
# 0                   [David Kirkland]
# 1                [Roy William Neill]
# 2  [Buster Keaton, John G. Blystone]
# 3                 [Cecil B. DeMille]
# 4                      [James Cruze]
#
#                                          writer_name
# 0                         [John Emerson, Anita Loos]
# 1   [Arthur F. Goodrich, Burns Mantle, Mary Murillo]
# 2  [Jean C. Havez, Clyde Bruckman, Joseph A. Mitc...
# 3                                [Jeanie Macpherson]
# 4               [Max Miller, Wells Root, Jack Jevne]

# %% [markdown]
# ### Cleaning Data
# #### Setelah melakukan join table, maka sekarang adalah melakukan cleaning data terhadap data yang sudah dihasilkan.

# %%
#Melakukan drop terhadap kolom 'knownForTitles'
drop_base=df_base.drop(['knownForTitles'], axis=1)
print(drop_base.info())

#Mengganti nilai NULL pada kolom 'genres' dengan 'Unknown'
drop_base['genres']=drop_base['genres'].fillna('Unknown')

#Melakukan perhitungan jumlah nilai NULL pada tiap kolom
print(drop_base.isnull().sum())

#Mengganti nilai NULL pada kolom director_name dan writer_name dengan 'Unknown'
drop_base[['director_name','writer_name']]=drop_base[['director_name','writer_name']].fillna('Unknown')

#Karena value pada kolom genres terdapat multiple values, jadi akan diubah menjadi list of list
drop_base['genres']=drop_base['genres'].apply(lambda x: x.split(','))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1060 entries, 0 to 1059
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   cast_name       1060 non-null   object
#  1   tconst          1060 non-null   object
#  2   titleType       1060 non-null   object
#  3   primaryTitle    1060 non-null   object
#  4   originalTitle   1060 non-null   object
#  5   isAdult         1060 non-null   int64
#  6   startYear       1060 non-null   float64
#  7   endYear         110 non-null    float64
#  8   runtimeMinutes  1060 non-null   float64
#  9   genres          745 non-null    object
#  10  averageRating   1060 non-null   float64
#  11  numVotes        1060 non-null   int64
#  12  director_name   986 non-null    object
#  13  writer_name     986 non-null    object
# dtypes: float64(4), int64(2), object(8)
# memory usage: 124.2+ KB
# None
# cast_name           0
# tconst              0
# titleType           0
# primaryTitle        0
# originalTitle       0
# isAdult             0
# startYear           0
# endYear           950
# runtimeMinutes      0
# genres              0
# averageRating       0
# numVotes            0
# director_name      74
# writer_name        74
# dtype: int64

# %% [markdown]
# ### Reformat on df_base table
# #### Langkah selanjutnya adalah melakukan reformat pada tabel df_base dimana beberapa kolomnya sudah didrop.

# %%
#Drop kolom tconst, isAdult, endYear, originalTitle
drop_base_kedua=drop_base.drop(['tconst', 'isAdult', 'endYear', 'originalTitle'], axis=1)

drop_base_kedua=drop_base_kedua[['primaryTitle', 'titleType', 'startYear', 'runtimeMinutes', 'genres', 
                                'averageRating', 'numVotes', 'cast_name', 'director_name', 'writer_name']]

drop_base_kedua.columns=['title', 'type', 'start', 'duration', 'genres', 'rating', 'votes', 'cast_name', 
                         'director_name', 'writer_name']

drop_base_kedua
# Out:
#                        title          type   start  duration  \
# 0            The Love Expert         movie  1920.0      60.0
# 1                  Yes or No         movie  1920.0      72.0
# 2            Our Hospitality         movie  1923.0      65.0
# 3          The King of Kings         movie  1927.0     155.0
# 4     I Cover the Waterfront         movie  1933.0      80.0
# ...                      ...           ...     ...       ...
# 1055             UFC on ESPN      tvSeries  2019.0     180.0
# 1056                  Bozkir  tvMiniSeries  2018.0      50.0
# 1057              Blue Story         movie  2019.0      91.0
# 1058              Typewriter      tvSeries  2019.0      48.0
# 1059         Koko-di Koko-da         movie  2019.0      86.0
#
#                            genres  rating  votes              cast_name  \
# 0               [Comedy, Romance]     4.9    136     [Natalie Talmadge]
# 1                       [Unknown]     6.3      7     [Natalie Talmadge]
# 2     [Comedy, Romance, Thriller]     7.8   9621     [Natalie Talmadge]
# 3     [Biography, Drama, History]     7.3   1826        [Reeka Roberts]
# 4                [Drama, Romance]     6.3    455        [James Hackett]
# ...                           ...     ...    ...                    ...
# 1055                    [Unknown]     8.1     38       [Vanessa Hanson]
# 1056      [Crime, Drama, Mystery]     8.2   1231          [Utku Arslan]
# 1057               [Crime, Drama]     5.5   1411     [Jonathon Deering]
# 1058           [Horror, Thriller]     6.5   2895         [Sandini Dhar]
# 1059    [Comedy, Fantasy, Horror]     6.2    779  [Lars-Gunnar Thorell]
#
#                           director_name  \
# 0                      [David Kirkland]
# 1                   [Roy William Neill]
# 2     [Buster Keaton, John G. Blystone]
# 3                    [Cecil B. DeMille]
# 4                         [James Cruze]
# ...                                 ...
# 1055                            Unknown
# 1056                     [Bahadir Ince]
# 1057                           [Rapman]
# 1058                      [Sujoy Ghosh]
# 1059                  [Johannes Nyholm]
#
#                                             writer_name
# 0                            [John Emerson, Anita Loos]
# 1      [Arthur F. Goodrich, Burns Mantle, Mary Murillo]
# 2     [Jean C. Havez, Clyde Bruckman, Joseph A. Mitc...
# 3                                   [Jeanie Macpherson]
# 4                  [Max Miller, Wells Root, Jack Jevne]
# ...                                                 ...
# 1055                                            Unknown
# 1056        [Levent Cantek, Ali Demirel, Baris Erdogan]
# 1057                                           [Rapman]
# 1058  [Sujoy Ghosh, Raj Vasant, Pratim D. Gupta, Sur...
# 1059                                  [Johannes Nyholm]
#
# [1060 rows x 10 columns]

# %%
drop_base_kedua.shape
# Out:
# (1060, 10)

# %%
drop_base_kedua.head()
# Out:
#                     title   type   start  duration  \
# 0         The Love Expert  movie  1920.0      60.0
# 1               Yes or No  movie  1920.0      72.0
# 2         Our Hospitality  movie  1923.0      65.0
# 3       The King of Kings  movie  1927.0     155.0
# 4  I Cover the Waterfront  movie  1933.0      80.0
#
#                         genres  rating  votes           cast_name  \
# 0            [Comedy, Romance]     4.9    136  [Natalie Talmadge]
# 1                    [Unknown]     6.3      7  [Natalie Talmadge]
# 2  [Comedy, Romance, Thriller]     7.8   9621  [Natalie Talmadge]
# 3  [Biography, Drama, History]     7.3   1826     [Reeka Roberts]
# 4             [Drama, Romance]     6.3    455     [James Hackett]
#
#                        director_name  \
# 0                   [David Kirkland]
# 1                [Roy William Neill]
# 2  [Buster Keaton, John G. Blystone]
# 3                 [Cecil B. DeMille]
# 4                      [James Cruze]
#
#                                          writer_name
# 0                         [John Emerson, Anita Loos]
# 1   [Arthur F. Goodrich, Burns Mantle, Mary Murillo]
# 2  [Jean C. Havez, Clyde Bruckman, Joseph A. Mitc...
# 3                                [Jeanie Macpherson]
# 4               [Max Miller, Wells Root, Jack Jevne]

# %% [markdown]
# ### Creating Content Based Recommender System
# #### Dalam tahap ini dilakukan klasifikasi metadata, dimana klasifikasi berdasarkan genres, primaryName (cast_name), director_name, dan writer_name.

# %%
df_feature=drop_base_kedua[['title', 'cast_name', 'genres', 'director_name', 'writer_name']]

# %%
df_feature
# Out:
#                        title              cast_name  \
# 0            The Love Expert     [Natalie Talmadge]
# 1                  Yes or No     [Natalie Talmadge]
# 2            Our Hospitality     [Natalie Talmadge]
# 3          The King of Kings        [Reeka Roberts]
# 4     I Cover the Waterfront        [James Hackett]
# ...                      ...                    ...
# 1055             UFC on ESPN       [Vanessa Hanson]
# 1056                  Bozkir          [Utku Arslan]
# 1057              Blue Story     [Jonathon Deering]
# 1058              Typewriter         [Sandini Dhar]
# 1059         Koko-di Koko-da  [Lars-Gunnar Thorell]
#
#                            genres                      director_name  \
# 0               [Comedy, Romance]                   [David Kirkland]
# 1                       [Unknown]                [Roy William Neill]
# 2     [Comedy, Romance, Thriller]  [Buster Keaton, John G. Blystone]
# 3     [Biography, Drama, History]                 [Cecil B. DeMille]
# 4                [Drama, Romance]                      [James Cruze]
# ...                           ...                                ...
# 1055                    [Unknown]                            Unknown
# 1056      [Crime, Drama, Mystery]                     [Bahadir Ince]
# 1057               [Crime, Drama]                           [Rapman]
# 1058           [Horror, Thriller]                      [Sujoy Ghosh]
# 1059    [Comedy, Fantasy, Horror]                  [Johannes Nyholm]
#
#                                             writer_name
# 0                            [John Emerson, Anita Loos]
# 1      [Arthur F. Goodrich, Burns Mantle, Mary Murillo]
# 2     [Jean C. Havez, Clyde Bruckman, Joseph A. Mitc...
# 3                                   [Jeanie Macpherson]
# 4                  [Max Miller, Wells Root, Jack Jevne]
# ...                                                 ...
# 1055                                            Unknown
# 1056        [Levent Cantek, Ali Demirel, Baris Erdogan]
# 1057                                           [Rapman]
# 1058  [Sujoy Ghosh, Raj Vasant, Pratim D. Gupta, Sur...
# 1059                                  [Johannes Nyholm]
#
# [1060 rows x 5 columns]

# %%
df_feature.shape
# Out:
# (1060, 5)

# %%
df_feature.head()
# Out:
#                     title           cast_name                       genres  \
# 0         The Love Expert  [Natalie Talmadge]            [Comedy, Romance]
# 1               Yes or No  [Natalie Talmadge]                    [Unknown]
# 2         Our Hospitality  [Natalie Talmadge]  [Comedy, Romance, Thriller]
# 3       The King of Kings     [Reeka Roberts]  [Biography, Drama, History]
# 4  I Cover the Waterfront     [James Hackett]             [Drama, Romance]
#
#                        director_name  \
# 0                   [David Kirkland]
# 1                [Roy William Neill]
# 2  [Buster Keaton, John G. Blystone]
# 3                 [Cecil B. DeMille]
# 4                      [James Cruze]
#
#                                          writer_name
# 0                         [John Emerson, Anita Loos]
# 1   [Arthur F. Goodrich, Burns Mantle, Mary Murillo]
# 2  [Jean C. Havez, Clyde Bruckman, Joseph A. Mitc...
# 3                                [Jeanie Macpherson]
# 4               [Max Miller, Wells Root, Jack Jevne]

# %% [markdown]
# ### Cara membuat fungsi untuk strip spaces dari setiap row dan setiap elementnya:

# %% [raw]
# def sanitize(x):
#     try:
#         #kalau cell berisi list
#         if isinstance(x, list):
#             return [i.replace(' ','').lower() for i in x]
#         #kalau cell berisi string
#         else:
#             return [x.replace(' ','').lower()]
#     except:
#         print(x)
#
# #Kolom : cast_name, genres, writer_name, director_name
# feature_coloumn = ['cast_name','genres','writer_name','director_name']
#
# #Apply function sanitize
# for coloumn in feature_coloumn:
#     df_feature[coloumn]=df_feature[coloumn].apply(sanitize)

# %% [markdown]
# #### Membuat fungsi untuk membentuk metadata soup (menggabungkan semua feature menjadi satu bagian kalimat) untuk setiap judul film.

# %%
#Kolom yang digunakan adalah cast_name, genres, director_name, dan writer_name

def feature_soup(x):
    return ' '.join(x['cast_name']) + ' ' + ' '.join(x['genres']) + ' ' + ' '.join(x['director_name']) + ' ' + ' '.join(x['writer_name'])

#Menmbuat metadata soup menjadi satu kolom
df_feature['soup']=df_feature.apply(feature_soup, axis=1)
# Out:
# <ipython-input-46-6ef2d56f0e57>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_feature['soup']=df_feature.apply(feature_soup, axis=1)

# %% [markdown]
# ### Menyiapkan CountVectorizer (stop_word = English) dan fit dengan metadata soup yang telah didefinisikan diatas.
# #### CountVectorizer adalah tipe yang paling sederhana dari Vectorizer. Untuk penjelasan lebih mudah dijabarkan melalui contoh di bawah ini:

# %% [raw]
# Misalkan terdapat tiga text antara lain A, B, dan , C dengan text sebagai berikut:
# A : The sun is a star
# B : My Love is like a red, red rose
# C : Mary had a little lamb
#
# Sekarang text tersebut harus dikonversi menjadi bentuk vector dengan menggunakan CountVectorizer. Langkah-langkahnya adalah menghitung ukuran dari vocabulary. Vocabulary adalah jumlah dari kata unik yag ada dari text tersebut.
#
# Oleh karena itu, vocabulary dari ketiga set text tersebut adalah: 'the', 'sun', 'is', 'a', 'star', 'my', 'love', 'like', 'red', 'rose', 'mary', 'had', 'little', 'lamb'.
# Secara total, ukuran vocabulary adalah 14.
#
# Tetapi, ada juga vocabulary yang tidak termasuk stop_words (English), seperti: 'as', 'is', 'a', 'the', dan sebagainya karena vocabulary tersebut sudah common sekali.
#
# Dengan mengeliminasi stop_words, maka clean size vocabulary adalah 'like', 'little', 'lamb', 'love', 'mary', 'red', 'rose', 'sun', 'star'(ascending sorting alphabet).

# %%
#Import CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# #### Mendefinisikan CountVectorizer dan mengubah metadata soup diatas menjadi bentuk vector.

# %%
count=CountVectorizer(stop_words='english')
matrix_count=count.fit_transform(df_feature['soup'])

print(matrix_count)
# Out:
#   (0, 6343)	1
#   (0, 8502)	1
#   (0, 1697)	1
#   (0, 7445)	1
#   (0, 1967)	1
#   (0, 4639)	1
#   (0, 4300)	1
#   (0, 2489)	1
#   (0, 260)	1
#   (0, 5306)	1
#   (1, 6343)	1
#   (1, 8502)	1
#   (1, 8888)	1
#   (1, 7511)	1
#   (1, 9286)	1
#   (1, 6380)	1
#   (1, 363)	1
#   (1, 3266)	1
#   (1, 1205)	1
#   (1, 5559)	1
#   (1, 5683)	1
#   (1, 6258)	1
#   (2, 6343)	1
#   (2, 8502)	1
#   (2, 1697)	1
#   :	:
#   (1057, 2258)	1
#   (1057, 1813)	1
#   (1057, 4312)	1
#   (1057, 2017)	1
#   (1057, 7198)	2
#   (1058, 8634)	1
#   (1058, 3903)	1
#   (1058, 7157)	1
#   (1058, 3439)	1
#   (1058, 8400)	1
#   (1058, 3130)	2
#   (1058, 7656)	1
#   (1058, 2107)	1
#   (1058, 8389)	2
#   (1058, 8957)	1
#   (1058, 7028)	1
#   (1058, 6307)	1
#   (1059, 1697)	1
#   (1059, 3903)	1
#   (1059, 2640)	1
#   (1059, 4996)	1
#   (1059, 4299)	2
#   (1059, 3434)	1
#   (1059, 8627)	1
#   (1059, 6521)	2

# %%
print(matrix_count.shape)
# Out:
# (1060, 9639)

# %% [markdown]
# ### Membuat Model Similarity Antara Matrix Count
# #### Pada langkah ini, akan dilakukan perhitungan terhadap score cosine similarity dari setiap pasangan judul dengan berdasarkan semua kombinasi pasangan yang ada, dengan kata lain membuat 675 x 675 matrix, dimana cell di kolom i dan j menunjukkan score similarity antara judul i dan j. Disini dapat dengan mudah untuk melihat bahwa matrix ini simetris dan setiap elemen pada diagonal adalah 1, karena itu adalah similarity score dengan dirinya sendiri.
# #### Cosine similarity pada bagian ini menggunakan formula cosine similarity untuk membuat model. Scor cosine ini sangatlah berguna dan mudah untuk dihitung.
# #### Formula untuk perhitungan cosine similarity antara dua text adalah sebagai berikut:

# %% [markdown]
# $$ cosine(x,y) = (x.y^T)/(||x||.||y||) $$

# %% [markdown]
# #### Output yang didapat adalah antara range -1 sampai 1. Score yang hampir mencapai 1 artinya kedua entitas tersebut sangatlah mirip sedangkan score yang hampir mencapai -1 artinya kedua entitas tersebut adalah beda.

# %%
#Import cosine_similarity
from sklearn.metrics.pairwise import cosine_similarity

# %%
#Menggunakan cosine_similarity antara matrix_count
cosine_similarity_output=cosine_similarity(matrix_count, matrix_count)

print(cosine_similarity_output)
# Out:
# [[1.         0.18257419 0.40824829 ... 0.         0.         0.08451543]
#  [0.18257419 1.         0.1490712  ... 0.         0.         0.        ]
#  [0.40824829 0.1490712  1.         ... 0.         0.06085806 0.06900656]
#  ...
#  [0.         0.         0.         ... 1.         0.         0.        ]
#  [0.         0.         0.06085806 ... 0.         1.         0.06299408]
#  [0.08451543 0.         0.06900656 ... 0.         0.06299408 1.        ]]

# %% [markdown]
# ### Cara Membuat Content Based Recommender System
# #### Langkah selanjutnya yang harus dilakukan adalah melakukan reverse mapping dengan judul sebagai index-nya.

# %%
indices=pd.Series(df_feature.index, index=df_feature['title']).drop_duplicates()

def content_recommender(title):
    #Mendapatkan index dari judul film (title) yang disebutkan.
    idx=indices[title]

    #Menjadikan list dari array similarity cosine_similarity_output.
    #Hint: cosine_similarity_output[idx]
    similarity_score=list(enumerate(cosine_similarity_output[idx]))

    #Mengurutkan film dari similarity tertinggi sampai similarity terendah.
    similarity_score=sorted(similarity_score,key=lambda x: x[1],reverse=True)

    #Untuk mendapatkan list judul dari item ke-2 sampe ke-11.
    similarity_score=similarity_score[1:11]

    #Mendapatkan index dari judul-judul yang muncul di similarity_score.
    indices_film=[i[0] for i in similarity_score]

    #Dengan menggunakan iloc, maka dapat dipanggil balik berdasarkan index dari indices_film.
    return df_base.iloc[indices_film]

# %% [markdown]
# ### Mengaplikasikan dari function diatas untuk pencarian.

# %%
content_recommender('The Lion King')
# Out:
#     knownForTitles                   cast_name     tconst titleType  \
# 848      tt3040964  [Cristina Carrión Márquez]  tt3040964     movie
# 530      tt0848456              [Jessi Castro]  tt0848456     video
# 822      tt2552322               [Gizem Gülen]  tt2552322     movie
# 917      tt4498760          [Kaleigh Phillips]  tt4498760     movie
# 835      tt2798920             [Dan Churchill]  tt2798920     movie
# 158      tt0100192        [William Holden Jr.]  tt0100192   tvMovie
# 383      tt0286336          [Francisco Bretas]  tt0286336  tvSeries
# 237      tt0119796              [Jeff Kurzner]  tt0119796   tvMovie
# 664      tt1518812               [Andrew Pope]  tt1518812     movie
# 815      tt2481480                [Yana Karin]  tt2481480     movie
#
#                                           primaryTitle  \
# 848                                    The Jungle Book
# 530                         Sodom 2: The Bottom Feeder
# 822  Paddle Pop Adventures 2: Journey Into the Kingdom
# 917                                   Khali the Killer
# 835                                       Annihilation
# 158                        Mother Goose Rock 'n' Rhyme
# 383                       The Animals of Farthing Wood
# 237                               My Stepson, My Lover
# 664                                      Meek's Cutoff
# 815                                        Rob the Mob
#
#                                          originalTitle  isAdult  startYear  \
# 848                                    The Jungle Book        0     2016.0
# 530                         Sodom 2: The Bottom Feeder        1     2006.0
# 822  Paddle Pop Adventures 2: Journey Into the Kingdom        0     2012.0
# 917                                   Khali the Killer        0     2017.0
# 835                                       Annihilation        0     2018.0
# 158                        Mother Goose Rock 'n' Rhyme        0     1990.0
# 383                       The Animals of Farthing Wood        0     1993.0
# 237                               My Stepson, My Lover        0     1997.0
# 664                                      Meek's Cutoff        0     2010.0
# 815                                        Rob the Mob        0     2014.0
#
#      endYear  runtimeMinutes                      genres  averageRating  \
# 848      NaN           106.0      Adventure,Drama,Family            7.4
# 530      NaN           162.0       Adult,Adventure,Drama            5.0
# 822      NaN            88.0  Action,Adventure,Animation            4.7
# 917      NaN            89.0                 Crime,Drama            3.6
# 835      NaN           115.0      Adventure,Drama,Horror            6.9
# 158      NaN            96.0    Adventure,Family,Fantasy            7.6
# 383   1995.0            25.0   Adventure,Animation,Drama            8.3
# 237      NaN            93.0              Drama,Thriller            4.4
# 664      NaN           104.0               Drama,Western            6.5
# 815      NaN           104.0                 Crime,Drama            6.3
#
#      numVotes                           director_name  \
# 848    250994                           [Jon Favreau]
# 530         5                                     NaN
# 822        23                                     NaN
# 917       234                          [Jon Matthews]
# 835    260155                          [Alex Garland]
# 158       717                            [Jeff Stein]
# 383      3057  [Elphin Lloyd-Jones, Philippe Leclerc]
# 237       289                          [Mary Lambert]
# 664     11340                       [Kelly Reichardt]
# 815     10463                    [Raymond De Felitta]
#
#                                            writer_name
# 848                    [Justin Marks, Rudyard Kipling]
# 530                                                NaN
# 822                                                NaN
# 917                                     [Jon Matthews]
# 835                    [Alex Garland, Jeff VanderMeer]
# 158  [Rod Ash, Mark Curtiss, Linda Engelsiepen, Hil...
# 383  [Valerie Georgeson, Colin Dann, Jenny McDade, ...
# 237                                       [Ron Cutler]
# 664                                 [Jonathan Raymond]
# 815                               [Jonathan Fernandez]

# %%
content_recommender('Annihilation')
# Out:
#     knownForTitles                     cast_name     tconst titleType  \
# 843      tt2963090                [Navid Taheri]  tt2963090     short
# 530      tt0848456                [Jessi Castro]  tt0848456     video
# 616      tt1291580           [Harvey J. Alperin]  tt1291580     movie
# 637      tt1375666               [Dan Churchill]  tt1375666     movie
# 799      tt2333598                        [Alex]  tt2333598     movie
# 511      tt0796366  [Matthew Fuchs, Aida Caefer]  tt0796366     movie
# 974      tt6105098                  [Rainy Kala]  tt6105098     movie
# 979      tt6236554             [Colin Burroughs]  tt6236554     movie
# 630      tt1339050                  [Jeff Randy]  tt1339050     movie
# 237      tt0119796                [Jeff Kurzner]  tt0119796   tvMovie
#
#                      primaryTitle                 originalTitle  isAdult  \
# 843  Echoes in an Empty Apartment  Echoes in an Empty Apartment        0
# 530    Sodom 2: The Bottom Feeder    Sodom 2: The Bottom Feeder        1
# 616         Behind the Candelabra         Behind the Candelabra        0
# 637                     Inception                     Inception        0
# 799                       7 Boxes                       7 cajas        0
# 511                     Star Trek                     Star Trek        0
# 974                 The Lion King                 The Lion King        0
# 979                 Imperial Blue                 Imperial Blue        0
# 630   Aswang: A Journey Into Myth   Aswang: A Journey Into Myth        0
# 237          My Stepson, My Lover          My Stepson, My Lover        0
#
#      startYear  endYear  runtimeMinutes                     genres  \
# 843     2014.0      NaN            23.0        Drama,Mystery,Short
# 530     2006.0      NaN           162.0      Adult,Adventure,Drama
# 616     2013.0      NaN           118.0      Biography,Drama,Music
# 637     2010.0      NaN           148.0    Action,Adventure,Sci-Fi
# 799     2012.0      NaN           105.0      Adventure,Crime,Drama
# 511     2009.0      NaN           127.0    Action,Adventure,Sci-Fi
# 974     2019.0      NaN           118.0  Adventure,Animation,Drama
# 979     2019.0      NaN            90.0     Drama,Fantasy,Thriller
# 630     2008.0      NaN            81.0       Drama,Horror,Mystery
# 237     1997.0      NaN            93.0             Drama,Thriller
#
#      averageRating  numVotes                           director_name  \
# 843            8.4         5            [Cara E. Brewer, Alex Reyme]
# 530            5.0         5                                     NaN
# 616            7.0     39228                     [Steven Soderbergh]
# 637            8.8   1950039                     [Christopher Nolan]
# 799            7.1      5002  [Juan Carlos Maneglia, Tana Schémbori]
# 511            7.9    567224                           [J.J. Abrams]
# 974            6.9    185808                           [Jon Favreau]
# 979            7.9        16                              [Dan Moss]
# 630            6.9        26                          [Jordan Clark]
# 237            4.4       289                          [Mary Lambert]
#
#                                            writer_name
# 843               [Lindsay Lane, Alex Reyme, Ko Wills]
# 530                                                NaN
# 616  [Richard LaGravenese, Scott Thorson, Alex Thor...
# 637                                [Christopher Nolan]
# 799  [Juan Carlos Maneglia, Tito Chamorro, Tana Sch...
# 511    [Gene Roddenberry, Roberto Orci, Alex Kurtzman]
# 974  [Jonathan Roberts, Jeff Nathanson, Irene Mecch...
# 979                            [David Cecil, Dan Moss]
# 630               [Jordan Clark, Janice Santos Valdez]
# 237                                       [Ron Cutler]

# %%
content_recommender('Sodom 2: The Bottom Feeder')
# Out:
#     knownForTitles                   cast_name     tconst titleType  \
# 73       tt0075147             [Joaquín Parra]  tt0075147     movie
# 232      tt0119051            [Chris Kosloski]  tt0119051     movie
# 9        tt0028657            [Bernard Loftus]  tt0028657     movie
# 908      tt4276752                   [Figo Li]  tt4276752     movie
# 848      tt3040964  [Cristina Carrión Márquez]  tt3040964     movie
# 638      tt1377521               [Logan Olson]  tt1377521     short
# 803      tt2356464               [Sina Müller]  tt2356464     movie
# 954      tt5525846             [Vishal Sharma]  tt5525846     movie
# 15       tt0036400          [Tomohisa Higuchi]  tt0036400     movie
# 835      tt2798920             [Dan Churchill]  tt2798920     movie
#
#                                primaryTitle  \
# 73                         Robin and Marian
# 232                                The Edge
# 9                     Boss of Lonely Valley
# 908                            Xun long jue
# 848                         The Jungle Book
# 638  The Macabre World of Lavender Williams
# 803                                 Ostwind
# 954                           Yeh Hai India
# 15                          Sanshiro Sugata
# 835                            Annihilation
#
#                               originalTitle  isAdult  startYear  endYear  \
# 73                         Robin and Marian        0     1976.0      NaN
# 232                                The Edge        0     1997.0      NaN
# 9                     Boss of Lonely Valley        0     1937.0      NaN
# 908                            Xun long jue        0     2015.0      NaN
# 848                         The Jungle Book        0     2016.0      NaN
# 638  The Macabre World of Lavender Williams        0     2009.0      NaN
# 803                                 Ostwind        0     2013.0      NaN
# 954                           Yeh Hai India        0     2017.0      NaN
# 15                          Sugata Sanshirô        0     1943.0      NaN
# 835                            Annihilation        0     2018.0      NaN
#
#      runtimeMinutes                   genres  averageRating  numVotes  \
# 73            106.0  Adventure,Drama,Romance            6.5     10830
# 232           117.0   Action,Adventure,Drama            6.9     65673
# 9              60.0   Action,Adventure,Drama            6.2        41
# 908           127.0   Action,Adventure,Drama            6.0      3288
# 848           106.0   Adventure,Drama,Family            7.4    250994
# 638            26.0  Adventure,Drama,Fantasy            7.4        49
# 803           101.0   Adventure,Drama,Family            6.8      1350
# 954           128.0   Action,Adventure,Drama            5.4       174
# 15             79.0   Action,Adventure,Drama            6.8      4067
# 835           115.0   Adventure,Drama,Horror            6.9    260155
#
#            director_name                                 writer_name
# 73      [Richard Lester]                             [James Goldman]
# 232       [Lee Tamahori]                               [David Mamet]
# 9           [Ray Taylor]             [Frances Guihan, Forrest Brown]
# 908           [Wuershan]                 [Chia-Lu Chang, Muye Zhang]
# 848        [Jon Favreau]             [Justin Marks, Rudyard Kipling]
# 638       [Nick Delgado]                              [Nick Delgado]
# 803  [Katja von Garnier]  [Kristina Magdalena Henn, Lea Schmidbauer]
# 954          [Lom Harsh]                                 [Lom Harsh]
# 15      [Akira Kurosawa]             [Akira Kurosawa, Tsuneo Tomita]
# 835       [Alex Garland]             [Alex Garland, Jeff VanderMeer]

# %% [markdown]
# ### Pencarian dilakukan dengan cara mengetikkan judul film, sehingga akan ditampilkan 10 film yang memiliki similarity dengan film yang diketik.
